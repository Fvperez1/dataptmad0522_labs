# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
df = pd.read_csv('C:/Users/FVILLALOBOS/Ironhack/dataptmad0522_labs/module-2/advanced-pandas/admissions_predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.
# df.columns

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
df = pd.DataFrame.from_dict(df)
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %%
# your code here

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
df = df.dropna()
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         385 non-null    int64
#  1   GRE Score          385 non-null    int64
#  2   TOEFL Score        385 non-null    int64
#  3   University Rating  385 non-null    int64
#  4   SOP                385 non-null    float64
#  5   LOR                385 non-null    float64
#  6   CGPA               385 non-null    float64
#  7   Research           385 non-null    int64
#  8   Chance of Admit    385 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 27.2 KB

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
df.set_index("Serial No.", drop=False)
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
# ...                ...        ...          ...                ...  ...  ...
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 384                384        312          103                  3  3.5  4.0
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90
# ...          ...       ...              ...
# 381         9.04         1             0.82
# 382         9.11         1             0.84
# 383         9.45         1             0.91
# 384         8.78         0             0.67
# 385         9.66         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here
print(len(df["GRE Score"].unique()))
print(len(df["CGPA"].unique()))
# Out:
# 49
# 168

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
df.set_index(["GRE Score", "CGPA"], inplace=True)
df
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 337       9.65           1          118                  4  4.5  4.5
# 316       8.00           2          104                  3  3.0  3.5
# 322       8.67           3          110                  3  3.5  2.5
# 314       8.21           4          103                  2  2.0  3.0
# 330       9.34           5          115                  5  4.5  3.0
# ...                    ...          ...                ...  ...  ...
# 324       9.04         381          110                  3  3.5  3.5
# 325       9.11         382          107                  3  3.0  3.5
# 330       9.45         383          116                  4  5.0  4.5
# 312       8.78         384          103                  3  3.5  4.0
# 333       9.66         385          117                  4  5.0  4.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1             0.92
# 316       8.00         1             0.72
# 322       8.67         1             0.80
# 314       8.21         0             0.65
# 330       9.34         1             0.90
# ...                  ...              ...
# 324       9.04         1             0.82
# 325       9.11         1             0.84
# 330       9.45         1             0.91
# 312       8.78         0             0.67
# 333       9.66         1             0.95
#
# [385 rows x 7 columns]

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.
# df = df.reset_index(inplace=True)
# df

# %%
# your code here
df.reset_index(inplace=True)
df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here
df[(df["CGPA"] > 9) & (df["Research"]==1)]
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 4          330  9.34           5          115                  5  4.5  3.0
# 10         328  9.10          11          112                  4  4.0  4.5
# 19         328  9.50          20          116                  5  5.0  5.0
# 20         334  9.70          21          119                  5  5.0  4.5
# ..         ...   ...         ...          ...                ...  ...  ...
# 379        329  9.23         380          111                  4  4.5  4.0
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 4           1             0.90
# 10          1             0.78
# 19          1             0.94
# 20          1             0.95
# ..        ...              ...
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 384         1             0.95
#
# [101 rows x 9 columns]

# %%
df[(df["CGPA"] > 9) & (df["Research"]==1)].count()
# Out:
# GRE Score            101
# CGPA                 101
# Serial No.           101
# TOEFL Score          101
# University Rating    101
# SOP                  101
# LOR                  101
# Research             101
# Chance of Admit      101
# dtype: int64

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
mean = df[(df["CGPA"] > 9) & (df["SOP"]<3.5)]
mean
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 28         338  9.40          29          118                  4  3.0  4.5
# 62         327  9.02          63          114                  3  3.0  3.0
# 140        326  9.11         141          114                  3  3.0  3.0
# 217        324  9.01         218          111                  4  3.0  3.0
# 381        325  9.11         382          107                  3  3.0  3.5
#
#      Research  Chance of Admit
# 28          1             0.91
# 62          0             0.61
# 140         1             0.83
# 217         1             0.82
# 381         1             0.84

# %%
mean.mean()
# Out:
# GRE Score            328.000
# CGPA                   9.130
# Serial No.           166.600
# TOEFL Score          112.800
# University Rating      3.400
# SOP                    3.000
# LOR                    3.400
# Research               0.800
# Chance of Admit        0.802
# dtype: float64

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    # your code here
    return (col-np.mean(col))/np.std(col)

# %%
print(np.mean(df['CGPA']))
print(np.std(df['CGPA']))
# Out:
# 8.597090909090909
# 0.6016024959756305

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here
df['CGPA_std'] = standardize(df['CGPA'])
df['GRE_std'] = standardize(df['GRE Score'])
df['LOR_std'] = standardize(df['LOR'])
df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0           1             0.92  1.750174  1.755663  1.193197
# 1           1             0.72 -0.992501 -0.063450  0.076840
# 2           1             0.80  0.121191  0.456297 -1.039517
# 3           0             0.65 -0.643433 -0.236698 -0.481338
# 4           1             0.90  1.234884  1.149292 -0.481338
# ..        ...              ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840
# 381         1             0.84  0.852571  0.716170  0.076840
# 382         1             0.91  1.417729  1.149292  1.193197
# 383         0             0.67  0.304036 -0.409947  0.635019
# 384         1             0.95  1.766796  1.409165  0.635019
#
# [385 rows x 12 columns]

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=df.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
df['deciding_column'] = df.lookup(df.index, decision_choice)
df
# Out:
# C:\Users\FVILLALOBOS\AppData\Local\Temp\ipykernel_25008\4192537235.py:2: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   df['deciding_column'] = df.lookup(df.index, decision_choice)
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column
# 0           1             0.92  1.750174  1.755663  1.193197         1.755663
# 1           1             0.72 -0.992501 -0.063450  0.076840        -0.063450
# 2           1             0.80  0.121191  0.456297 -1.039517         0.121191
# 3           0             0.65 -0.643433 -0.236698 -0.481338        -0.481338
# 4           1             0.90  1.234884  1.149292 -0.481338         1.149292
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.736216  0.629546  0.076840         0.736216
# 381         1             0.84  0.852571  0.716170  0.076840         0.852571
# 382         1             0.91  1.417729  1.149292  1.193197         1.193197
# 383         0             0.67  0.304036 -0.409947  0.635019         0.304036
# 384         1             0.95  1.766796  1.409165  0.635019         1.766796
#
# [385 rows x 13 columns]

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
df['decision'] = np.where(df['deciding_column']> 0.8, 1, 0)
df.head()
# Out:
#    GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0        337  9.65           1          118                  4  4.5  4.5
# 1        316  8.00           2          104                  3  3.0  3.5
# 2        322  8.67           3          110                  3  3.5  2.5
# 3        314  8.21           4          103                  2  2.0  3.0
# 4        330  9.34           5          115                  5  4.5  3.0
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0         1             0.92  1.750174  1.755663  1.193197         1.755663
# 1         1             0.72 -0.992501 -0.063450  0.076840        -0.063450
# 2         1             0.80  0.121191  0.456297 -1.039517         0.121191
# 3         0             0.65 -0.643433 -0.236698 -0.481338        -0.481338
# 4         1             0.90  1.234884  1.149292 -0.481338         1.149292
#
#    decision
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here
df[df['decision']==1]
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 4          330  9.34           5          115                  5  4.5  3.0
# 9          327  9.00          10          111                  4  4.0  4.5
# 10         328  9.10          11          112                  4  4.0  4.5
# 19         328  9.50          20          116                  5  5.0  5.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 370        335  9.82         371          117                  5  5.0  5.0
# 379        329  9.23         380          111                  4  4.5  4.0
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0           1             0.92  1.750174  1.755663  1.193197         1.755663
# 4           1             0.90  1.234884  1.149292 -0.481338         1.149292
# 9           1             0.84  0.669726  0.889419  1.193197         0.889419
# 10          1             0.78  0.835949  0.976043  1.193197         1.193197
# 19          1             0.94  1.500840  0.976043  1.751376         1.500840
# ..        ...              ...       ...       ...       ...              ...
# 370         1             0.96  2.032753  1.582414  1.751376         2.032753
# 379         1             0.89  1.052039  1.062667  0.635019         1.052039
# 381         1             0.84  0.852571  0.716170  0.076840         0.852571
# 382         1             0.91  1.417729  1.149292  1.193197         1.193197
# 384         1             0.95  1.766796  1.409165  0.635019         1.766796
#
#      decision
# 0           1
# 4           1
# 9           1
# 10          1
# 19          1
# ..        ...
# 370         1
# 379         1
# 381         1
# 382         1
# 384         1
#
# [90 rows x 14 columns]

# %%
df[df['decision']==1].count()
# Out:
# GRE Score            90
# CGPA                 90
# Serial No.           90
# TOEFL Score          90
# University Rating    90
# SOP                  90
# LOR                  90
# Research             90
# Chance of Admit      90
# CGPA_std             90
# GRE_std              90
# LOR_std              90
# deciding_column      90
# decision             90
# dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here
import re
columns = df.columns.str.replace('.', '').str.replace(" ","_").str.lower()
df.columns = columns
df
# Out:
# C:\Users\FVILLALOBOS\AppData\Local\Temp\ipykernel_25008\2046996620.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   columns = df.columns.str.replace('.', '').str.replace(" ","_").str.lower()
#      gre_score  cgpa  serial_no  toefl_score  university_rating  sop  lor  \
# 0          337  9.65          1          118                  4  4.5  4.5
# 1          316  8.00          2          104                  3  3.0  3.5
# 2          322  8.67          3          110                  3  3.5  2.5
# 3          314  8.21          4          103                  2  2.0  3.0
# 4          330  9.34          5          115                  5  4.5  3.0
# ..         ...   ...        ...          ...                ...  ...  ...
# 380        324  9.04        381          110                  3  3.5  3.5
# 381        325  9.11        382          107                  3  3.0  3.5
# 382        330  9.45        383          116                  4  5.0  4.5
# 383        312  8.78        384          103                  3  3.5  4.0
# 384        333  9.66        385          117                  4  5.0  4.0
#
#      research  chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  \
# 0           1             0.92  1.750174  1.755663  1.193197         1.755663
# 1           1             0.72 -0.992501 -0.063450  0.076840        -0.063450
# 2           1             0.80  0.121191  0.456297 -1.039517         0.121191
# 3           0             0.65 -0.643433 -0.236698 -0.481338        -0.481338
# 4           1             0.90  1.234884  1.149292 -0.481338         1.149292
# ..        ...              ...       ...       ...       ...              ...
# 380         1             0.82  0.736216  0.629546  0.076840         0.736216
# 381         1             0.84  0.852571  0.716170  0.076840         0.852571
# 382         1             0.91  1.417729  1.149292  1.193197         1.193197
# 383         0             0.67  0.304036 -0.409947  0.635019         0.304036
# 384         1             0.95  1.766796  1.409165  0.635019         1.766796
#
#      decision
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 380         0
# 381         1
# 382         1
# 383         0
# 384         1
#
# [385 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gre_score          385 non-null    int64
#  1   cgpa               385 non-null    float64
#  2   serial_no          385 non-null    int64
#  3   toefl_score        385 non-null    int64
#  4   university_rating  385 non-null    int64
#  5   sop                385 non-null    float64
#  6   lor                385 non-null    float64
#  7   research           385 non-null    int64
#  8   chance_of_admit    385 non-null    float64
#  9   cgpa_std           385 non-null    float64
#  10  gre_std            385 non-null    float64
#  11  lor_std            385 non-null    float64
#  12  deciding_column    385 non-null    float64
#  13  decision           385 non-null    int32
# dtypes: float64(8), int32(1), int64(5)
# memory usage: 40.7 KB

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
df[df["university_rating"]>=4 & (df["gre_score"]+10)]
# Out:
#      gre_score  cgpa  serial_no  toefl_score  university_rating  sop  lor  \
# 0          337  9.65          1          118                  4  4.5  4.5
# 4          330  9.34          5          115                  5  4.5  3.0
# 5          321  8.20          6          109                  3  3.0  4.0
# 7          302  8.00          8          102                  1  2.0  1.5
# 9          327  9.00         10          111                  4  4.0  4.5
# ..         ...   ...        ...          ...                ...  ...  ...
# 377        326  9.12        378          112                  4  4.0  3.5
# 379        329  9.23        380          111                  4  4.5  4.0
# 382        330  9.45        383          116                  4  5.0  4.5
# 383        312  8.78        384          103                  3  3.5  4.0
# 384        333  9.66        385          117                  4  5.0  4.0
#
#      research  chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  \
# 0           1             0.92  1.750174  1.755663  1.193197         1.755663
# 4           1             0.90  1.234884  1.149292 -0.481338         1.149292
# 5           1             0.75 -0.660055  0.369672  0.635019        -0.660055
# 7           0             0.50 -0.992501 -1.276191 -2.155874        -1.276191
# 9           1             0.84  0.669726  0.889419  1.193197         0.889419
# ..        ...              ...       ...       ...       ...              ...
# 377         1             0.84  0.869194  0.802794  0.076840         0.076840
# 379         1             0.89  1.052039  1.062667  0.635019         1.052039
# 382         1             0.91  1.417729  1.149292  1.193197         1.193197
# 383         0             0.67  0.304036 -0.409947  0.635019         0.304036
# 384         1             0.95  1.766796  1.409165  0.635019         1.766796
#
#      decision
# 0           1
# 4           1
# 5           0
# 7           0
# 9           1
# ..        ...
# 377         0
# 379         1
# 382         1
# 383         0
# 384         1
#
# [251 rows x 14 columns]

# %%
df["adjusted_gre"] = pd.cut(df["gre_score"], 4)
df["adjusted_gre"]
# Out:
# 0      (327.5, 340.0]
# 1      (315.0, 327.5]
# 2      (315.0, 327.5]
# 3      (302.5, 315.0]
# 4      (327.5, 340.0]
#             ...
# 380    (315.0, 327.5]
# 381    (315.0, 327.5]
# 382    (327.5, 340.0]
# 383    (302.5, 315.0]
# 384    (327.5, 340.0]
# Name: adjusted_gre, Length: 385, dtype: category
# Categories (4, interval[float64, right]): [(289.95, 302.5] < (302.5, 315.0] < (315.0, 327.5] < (327.5, 340.0]]
